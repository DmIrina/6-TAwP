# %%
import numpy as np
import pandas as pd
import nltk

# %% [markdown]
# #### Task 1

# %% [markdown]
# Застосувати приховане семантичне індексування бібліотеки scikit-learn для моделювання тем.
# Вивести документи, що зробили найбільший вклад в теми.
# Вивести документи, що описують кожну з тем.

# %%
data_df = pd.read_csv('news.csv')

# %%
import re

wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')


def preproc_doc(doc):
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = re.sub(r'http\S+', '', doc)
    doc = doc.lower()
    doc = doc.strip()
    tokens = wpt.tokenize(doc)
    filtered_tokens = [token for token in tokens if token not in stop_words]
    doc = ' '.join(filtered_tokens)
    return doc


preproc_corpus = np.vectorize(preproc_doc)
documents = preproc_corpus(data_df['text'])
documents
# Out:
# array(['thursdays biggest analyst calls apple amazon tesla palantir docusign exxon amp',
#        'buy las vegas sands travel singapore builds wells fargo says',
#        'piper sandler downgrades docusign sell citing elevated risks amid ceo transition',
#        ..., 'russian sells bln roubles oneyear repo auction',
#        'global esg bond issuance posts h dip supranationals cut back',
#        'brazils petrobras says signed billion sustainability loan'],
#       dtype='<U240')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

vectorizer = TfidfVectorizer()
matrix = vectorizer.fit_transform(documents)

# %%
num_topics = 10

lsa_model = TruncatedSVD(n_components=num_topics)
lsa_matrix = lsa_model.fit_transform(matrix)
top_documents = lsa_matrix.argmax(axis=0)

for topic_index, document_index in enumerate(top_documents):
    print(f"Topic {topic_index}: {documents[document_index]}")
# Out:
# Topic 0: webcast second quarter financial results conference call
# Topic 1: dividend growth stocks july stocks finance markets
# Topic 2: wires wires
# Topic 3: autonation inc q results earnings call presentation investing stocks stockmarket
# Topic 4: c citigroup gaap eps beats revenue b beats b
# Topic 5: labcorp declares quarterly dividend
# Topic 6: first trust global funds plc uk regulatory announcement net asset values
# Topic 7: announces date second quarter earnings release conference call
# Topic 8: us cpi mom jun actual vs previous est us cpi yoy jun actual vs previous est us core cpi mom jun actual vs previous est us core cpi yoy jun actual vs previous est
# Topic 9: company sues elon musk attempting back billion deal

# %%
num_words = 5
topics = lsa_model.components_

for topic_index, topic in enumerate(topics):
    top_words_indices = topic.argsort()[:-num_words - 1:-1]
    top_words = [vectorizer.get_feature_names_out()[i] for i in top_words_indices]
    print(f"Topic {topic_index}: {' '.join(top_words)}")
# Out:
# Topic 0: quarter second results earnings call
# Topic 1: stocks markets economy us business
# Topic 2: wires year firm investors revenue
# Topic 3: investing stockmarket business stocks trading
# Topic 4: beats eps revenue gaap revs
# Topic 5: dividend declares quarterly share distribution
# Topic 6: uk announcement regulatory plc form
# Topic 7: earnings call announces conference est
# Topic 8: est vs jun prev actual
# Topic 9: new musk elon company billion

# %% [markdown]
# #### Task 2

# %% [markdown]
# Використати текст chesterton-thursday.txt з корпусу gutenberg бібліотеки nltk та вивести ключові біграми.

# %%
from nltk.corpus import gutenberg
from string import punctuation

chesterton = gutenberg.sents('chesterton-thursday.txt')
remove_terms = punctuation + '0123456789'
thursday = [[word.lower() for word in sent if word not in remove_terms] for sent in chesterton]
thursday = [' '.join(tok_sent) for tok_sent in thursday]
thursday = filter(None, preproc_corpus(thursday))
thursday = [tok_sent for tok_sent in thursday if len(tok_sent.split()) > 2]
thursday
# Out:
# ['man thursday g k chesterton',
#  'edmund clerihew bentley',
#  'cloud mind men wailing went weather yea sick cloud upon soul boys together',
#  'science announced nonentity art admired decay world old ended gay round us antic order crippled vices came lust lost laughter fear lost shame',
#  'like white lock whistler lit aimless gloom men showed white feather proudly plume',
#  'life fly faded death drone stung world old indeed young',
#  'twisted even decent sin shapes named men ashamed honour ashamed',
#  'weak foolish thus failed thus black baal blocked heavens hymns us children forts sand even weak eve high went piled break bitter sea',
#  'fools motley jangling absurd church bells silent cap beds heard',
#  'unhelped held fort tiny flags unfurled giants laboured cloud lift world',
#  'find book found feel hour flings far fish shaped paumanok cry cleaner things green carnation withered forest fires pass roared wind world ten million leaves grass sane sweet sudden bird sings rain truth tusitala spoke pleasure pain',
#  'yea cool clear sudden bird sings grey dunedin samoa spoke darkness unto day',
#  'young lived see god break bitter charms',
#  'god good republic come riding back arms seen city mansoul even rocked relieved blessed see blind believed',
#  'tale old fears even emptied hells none shall understand true thing tells colossal gods shame could cow men yet crash huge devils hid stars yet fell pistol flash',
#  'doubts plain chase dreadful withstand oh shall understand yea shall understand',
#  'doubts drove us night two talked amain day broken streets e er broke upon brain',
#  'us peace god truth told yea strength striking root good growing old',
#  'found common things last marriage creed may safely write may safely read',
#  'g k c',
#  'two poets saffron park',
#  'suburb saffron park lay sunset side london red ragged cloud sunset',
#  'built bright brick throughout sky line fantastic even ground plan wild',
#  'outburst speculative builder faintly tinged art called architecture sometimes elizabethan sometimes queen anne apparently impression two sovereigns identical',
#  'described justice artistic colony though never definable way produced art',
#  'although pretensions intellectual centre little vague pretensions pleasant place quite indisputable',
#  'stranger looked first time quaint red houses could think oddly shaped people must could fit',
#  'met people disappointed respect',
#  'place pleasant perfect could regard deception rather dream',
#  'even people artists whole nevertheless artistic',
#  'young man long auburn hair impudent face young man really poet surely poem',
#  'old gentleman wild white beard wild white hat venerable humbug really philosopher least cause philosophy others',
#  'scientific gentleman bald egg like head bare bird like neck real right airs science assumed',
#  'discovered anything new biology biological creature could discovered singular',
#  'thus thus whole place properly regarded considered much workshop artists frail finished work art',
#  'man stepped social atmosphere felt stepped written comedy',
#  'especially attractive unreality fell upon nightfall extravagant roofs dark afterglow whole insane village seemed separate drifting cloud',
#  'strongly true many nights local festivity little gardens often illuminated big chinese lanterns glowed dwarfish trees like fierce monstrous fruit',
#  'strongest one particular evening still vaguely remembered locality auburn haired poet hero',
#  'means evening hero',
#  'many nights passing little back garden might hear high didactic voice laying law men particularly women',
#  'attitude women cases indeed one paradoxes place',
#  'women kind vaguely called emancipated professed protest male supremacy',
#  'yet new women would always pay man extravagant compliment ordinary woman ever pays listening talking',
#  'mr lucian gregory red haired poet really sense man worth listening even one laughed end',
#  'put old cant lawlessness art art lawlessness certain impudent freshness gave least momentary pleasure',
#  'helped degree arresting oddity appearance worked phrase goes worth',
#  'dark red hair parted middle literally like woman curved slow curls virgin pre raphaelite picture',
#  'within almost saintly oval however face projected suddenly broad brutal chin carried forward look cockney contempt',
#  'combination tickled terrified nerves neurotic population',
#  'seemed like walking blasphemy blend angel ape',
#  'particular evening remembered nothing else remembered place strange sunset',
#  'looked like end world',
#  'heaven seemed covered quite vivid palpable plumage could say sky full feathers feathers almost brushed face',
#  'across great part dome grey strangest tints violet mauve unnatural pink pale green towards west whole grew past description transparent passionate last red hot plumes covered sun like something good seen',
#  'whole close earth express nothing violent secrecy',
#  'empyrean seemed secret',
#  'expressed splendid smallness soul local patriotism',
#  'sky seemed small',
#  'say inhabitants may remember evening oppressive sky',
#  'others may remember marked first appearance place second poet saffron park',
#  'long time red haired revolutionary reigned without rival upon night sunset solitude suddenly ended',
#  'new poet introduced name gabriel syme mild looking mortal fair pointed beard faint yellow hair',
#  'impression grew less meek looked',
#  'signalised entrance differing established poet gregory upon whole nature poetry',
#  'said syme poet law poet order nay said poet respectability',
#  'saffron parkers looked moment fallen impossible sky',
#  'fact mr lucian gregory anarchic poet connected two events',
#  'may well said sudden lyrical manner may well night clouds cruel colours brought forth upon earth portent respectable poet',
#  'say poet law say contradiction terms',
#  'wonder comets earthquakes night appeared garden',
#  'man meek blue eyes pale pointed beard endured thunders certain submissive solemnity',
#  'third party group gregory sister rosamond brother braids red hair kindlier face underneath laughed mixture admiration disapproval gave commonly family oracle',
#  'gregory resumed high oratorical good humour',
#  'artist identical anarchist cried',
#  'might transpose words anywhere',
#  'man throws bomb artist prefers great moment everything',
#  'sees much valuable one burst blazing light one peal perfect thunder mere common bodies shapeless policemen',
#  'artist disregards governments abolishes conventions',
#  'poet delights disorder',
#  'poetical thing world would underground railway',
#  'said mr syme',
#  'said gregory rational anyone else attempted paradox',
#  'clerks navvies railway trains look sad tired sad tired',
#  'know train going right',
#  'know whatever place taken ticket place reach',
#  'passed sloane square know next station must victoria nothing victoria',
#  'oh wild rapture',
#  'oh eyes like stars souls eden next station unaccountably baker street',
#  'unpoetical replied poet syme',
#  'say clerks true prosaic poetry',
#  'rare strange thing hit mark gross obvious thing miss',
#  'feel epical man one wild arrow strikes distant bird',
#  'also epical man one wild engine strikes distant station',
#  'chaos dull chaos train might indeed go anywhere baker street bagdad',
#  'man magician whole magic say victoria lo',
#  'take books mere poetry prose let read time table tears pride',
#  'take byron commemorates defeats man give bradshaw commemorates victories',
#  'give bradshaw say',
#  'inquired gregory sarcastically',
#  'tell went syme passion every time train comes feel broken past batteries besiegers man battle chaos',
#  'say contemptuously one left sloane square one must come victoria',
#  'say one might thousand things instead whenever really come sense hairbreadth escape',
#  'hear guard shout word victoria unmeaning word',
#  'cry herald announcing conquest',
#  'indeed victoria victory adam',
#  'gregory wagged heavy red head slow sad smile',
#  'even said poets always ask question victoria got',
#  'think victoria like new jerusalem',
#  'know new jerusalem like victoria',
#  'yes poet discontented even streets heaven',
#  'poet always revolt',
#  'said syme irritably poetical revolt',
#  'might well say poetical sea sick',
#  'sick rebellious may wholesome thing certain desperate occasions hanged see poetical',
#  'revolt abstract revolting',
#  'girl winced flash unpleasant word syme hot heed',
#  'things going right cried poetical digestions instance going sacredly silently right foundation poetry',
#  'yes poetical thing poetical flowers poetical stars poetical thing world sick',
#  'really said gregory superciliously examples choose',
#  'beg pardon said syme grimly forgot abolished conventions',
#  'first time red patch appeared gregory forehead',
#  'expect said revolutionise society lawn',
#  'syme looked straight eyes smiled sweetly',
#  'said suppose serious anarchism exactly would',
#  'gregory big bull eyes blinked suddenly like angry lion one could almost fancy red mane rose',
#  'think said dangerous voice serious anarchism',
#  'cried gregory knotted fists',
#  'said syme strolled away',
#  'surprise curious pleasure found rosamond gregory still company',
#  'mr syme said people talk like brother often mean say',
#  'asked girl grave eyes',
#  'dear miss gregory said syme gently many kinds sincerity insincerity',
#  'say thank salt mean say',
#  'say world round mean say',
#  'sometimes man like brother really finds thing mean',
#  'may half truth quarter truth tenth truth says means sheer force meaning',
#  'looking level brows face grave open fallen upon shadow unreasoning responsibility bottom frivolous woman maternal watch old world',
#  'sense speak replied syme prefer nonsense',
#  'drew broad brows together said abruptly',
#  'really use bombs sort thing',
#  'syme broke great laugh seemed large slight somewhat dandified figure',
#  'said done anonymously',
#  'corners mouth broke smile thought simultaneous pleasure gregory absurdity safety',
#  'syme strolled seat corner garden continued pour opinions',
#  'sincere man spite superficial airs graces root humble one',
#  'always humble man talks much proud man watches closely',
#  'defended respectability violence exaggeration',
#  'grew passionate praise tidiness propriety',
#  'time smell lilac round',
#  'heard faintly distant street barrel organ begin play seemed heroic words moving tiny tune beyond world',
#  'stared talked girl red hair amused face seemed minutes feeling groups place mix rose feet',
#  'astonishment discovered whole garden empty',
#  'everyone gone long ago went rather hurried apology',
#  'left sense champagne head could afterwards explain',
#  'wild events follow girl part never saw tale',
#  'yet indescribable way kept recurring like motive music mad adventures afterwards glory strange hair ran like red thread dark ill drawn tapestries night',
#  'followed improbable might well dream',
#  'syme went starlit street found moment empty',
#  'realised odd way silence rather living silence dead one',
#  'directly outside door stood street lamp whose gleam gilded leaves tree bent fence behind',
#  'foot lamp post stood figure almost rigid motionless lamp post',
#  'tall hat long frock coat black face abrupt shadow almost dark',
#  'fringe fiery hair light also something aggressive attitude proclaimed poet gregory',
#  'something look masked bravo waiting sword hand foe',
#  'made sort doubtful salute syme somewhat formally returned',
#  'waiting said gregory',
#  'might moment conversation',
#  'asked syme sort weak wonder',
#  'gregory struck stick lamp post tree',
#  'cried order anarchy',
#  'precious order lean iron lamp ugly barren anarchy rich living reproducing anarchy splendid green gold',
#  'replied syme patiently present see tree light lamp',
#  'wonder would ever see lamp light tree',
#  'pause said may ask standing dark resume little argument',
#  'cried gregory voice rang street stand resume argument end ever',
#  'silence fell syme though understood nothing listened instinctively something serious',
#  'gregory began smooth voice rather bewildering smile',
#  'mr syme said evening succeeded something rather remarkable',
#  'something man born woman ever succeeded',
#  'remember resumed gregory reflectively one person succeeded',
#  'captain penny steamer remember correctly southend',
#  'sorry replied syme gravity',
#  'afraid fury insult shocking wiped even apology said gregory calmly',
#  'duel could wipe',
#  'struck dead could wipe',
#  'one way insult erased way choose',
#  'going possible sacrifice life honour prove wrong said',
#  'said serious anarchist',
#  'degrees seriousness replied syme',
#  'never doubted perfectly sincere sense thought said well worth saying thought paradox might wake men neglected truth',
#  'gregory stared steadily painfully',
#  'sense asked think serious',
#  'think flaneur lets fall occasional truths',
#  'think deeper deadly sense serious',
#  'syme struck stick violently stones road',
#  'damned chinese lanterns serious',
#  'whole caboodle serious',
#  'one comes talks pack bosh perhaps sense well think little man keep something background life serious talking something serious whether religion drink',
#  'well said gregory face darkening shall see something serious either drink religion',
#  'syme stood waiting usual air mildness gregory opened lips',
#  'really true one',
#  'oh said syme beaming smile catholics',
#  'may ask swear whatever gods saints religion involves reveal going tell son adam especially police',
#  'take upon awful abnegations consent burden soul vow never make knowledge never dream promise return',
#  'inquired syme paused',
#  'promise entertaining evening',
#  'syme suddenly took hat',
#  'offer said far idiotic declined',
#  'say poet always anarchist',
#  'disagree hope least always sportsman',
#  'permit swear christian promise good comrade fellow artist report anything whatever police',
#  'name colney hatch',
#  'think said gregory placid irrelevancy call cab',
#  'gave two long whistles hansom came rattling road',
#  'two got silence',
#  'gregory gave trap address obscure public house chiswick bank river',
#  'cab whisked away two fantastics quitted fantastic town',
#  'secret gabriel syme',
#  'cab pulled particularly dreary greasy beershop gregory rapidly conducted companion',
#  'seated close dim sort bar parlour stained wooden table one wooden leg',
#  'room small dark little could seen attendant summoned beyond vague dark impression something bulky bearded',
#  'take little supper',
#  'asked gregory politely',
#  'pate de foie gras good recommend game',
#  'syme received remark stolidity imagining joke',
#  'accepting vein humour said well bred indifference',
#  'oh bring lobster mayonnaise',
#  'indescribable astonishment man said certainly sir',
#  'went away apparently get',
#  'resumed gregory careless yet apologetic air',
#  'shall crepe de menthe dined',
#  'champagne really trusted',
#  'let start half bottle pommery least',
#  'said motionless syme',
#  'attempts conversation somewhat disorganised cut short finally thunderbolt actual appearance lobster',
#  'syme tasted found particularly good',
#  'suddenly began eat great rapidity appetite',
#  'excuse enjoy rather obviously',
#  'said gregory smiling',
#  'often luck dream like',
#  'new nightmare lead lobster',
#  'asleep assure said gregory',
#  'contrary close actual rousing moment existence',
#  'ah comes champagne',
#  'admit may slight disproportion let us say inner arrangements excellent hotel simple unpretentious exterior',
#  'modest men ever lived earth',
#  'asked syme emptying champagne glass',
#  'quite simple replied gregory',
#  'serious anarchists believe',
#  'said syme shortly',
#  'yes serious everything answered gregory',
#  'moments table begins turn round little put inroads champagne',
#  'well drunk mad replied syme perfect calm trust behave like gentleman either condition',
#  'said gregory producing cigar case',
#  'try one mine',
#  'syme took cigar clipped end cigar cutter waistcoat pocket put mouth lit slowly let long cloud smoke',
#  'little credit performed rites much composure almost begun table sat begun revolve first slowly rapidly insane seance',
#  'must mind said gregory kind screw',
#  'quite said syme placidly kind screw',
#  'next moment smoke cigar wavering across room snaky twists went straight factory chimney two chairs table shot floor earth swallowed',
#  'went rattling kind roaring chimney rapidly lift cut loose came abrupt bump bottom',
#  'gregory threw open pair doors let red subterranean light syme still smoking one leg thrown turned yellow hair',
#  'gregory led low vaulted passage end red light',
#  'enormous crimson lantern nearly big fireplace fixed small heavy iron door',
#  'door sort hatchway grating gregory struck five times',
#  'heavy voice foreign accent asked',
#  'gave less unexpected reply mr joseph chamberlain',
#  'heavy hinges began move obviously kind password',
#  'inside doorway passage gleamed lined network steel',
#  'second glance syme saw glittering pattern really made ranks ranks rifles revolvers closely packed interlocked',
#  'must ask forgive formalities said gregory strict',
#  'oh apologise said syme',
#  'know passion law order stepped passage lined steel weapons',
#  'long fair hair rather foppish frock coat looked singularly frail fanciful figure walked shining avenue death',
#  'passed several passages came last queer steel chamber curved walls almost spherical shape presenting tiers benches something appearance scientific lecture theatre',
#  'rifles pistols apartment round walls hung dubious dreadful shapes things looked like bulbs iron plants eggs iron birds',
#  'bombs room seemed like inside bomb',
#  'syme knocked cigar ash wall went',
#  'dear mr syme said gregory throwing expansive manner bench largest bomb quite cosy let us talk properly',
#  'human words give notion brought',
#  'one quite arbitrary emotions like jumping cliff falling love',
#  'suffice say inexpressibly irritating fellow justice still',
#  'would break twenty oaths secrecy pleasure taking peg',
#  'way lighting cigar would make priest break seal confession',
#  'well said quite certain serious anarchist',
#  'place strike serious',
#  'seem moral gaiety assented syme may ask two questions',
#  'need fear give information remember wisely extorted promise tell police promise shall certainly keep',
#  'mere curiosity make queries',
#  'want abolish government',
#  'said gregory opening eyes fanatic',
#  'want upset despotisms police regulations sort anarchism exist mere branch nonconformists',
#  'dig deeper blow higher',
#  'wish deny arbitrary distinctions vice virtue honour treachery upon mere rebels base',
#  'silly sentimentalists french revolution talked rights man',
#  'hate rights hate wrongs',
#  'abolished right wrong',
#  'right left said syme simple eagerness hope abolish',
#  'spoke second question snapped gregory',
#  'pleasure resumed syme',
#  'present acts surroundings scientific attempt secrecy',
#  'aunt lived shop first time found people living preference public house',
#  'heavy iron door',
#  'cannot pass without submitting humiliation calling mr chamberlain',
#  'surround steel instruments make place may say impressive homelike',
#  'may ask taking trouble barricade bowels earth parade whole secret talking anarchism every silly woman saffron park',
#  'answer simple said',
#  'told serious anarchist believe',
#  'unless took infernal room would believe',
#  'syme smoked thoughtfully looked interest',
#  'history thing might amuse said',
#  'first became one new anarchists tried kinds respectable disguises',
#  'read bishops anarchist pamphlets superstition vampire priests prey',
#  'certainly understood bishops strange terrible old men keeping cruel secret mankind',
#  'first appearing episcopal gaiters drawing room cried voice thunder',
#  'presumptuous human reason',
#  'found way bishop',
#  'made millionaire defended capital much intelligence fool could see quite poor',
#  'humanitarian hope enough intellectual breadth understand position like nietzsche admire violence proud mad war nature know',
#  'drew sword waved constantly',
#  'abstractedly like man calling wine',
#  'often said let weak perish law',
#  'well well seems majors',
#  'last went despair president central anarchist council greatest man europe',
#  'would know answered gregory',
#  'caesar napoleon put genius heard heard',
#  'puts genius heard heard',
#  'cannot five minutes room without feeling caesar napoleon would children hands',
#  'silent even pale moment resumed',
#  'whenever gives advice always something startling epigram yet practical bank england',
#  'said disguise hide world',
#  'find respectable bishops majors',
#  'looked large indecipherable face',
#  'want safe disguise',
#  'want dress guarantee harmless dress one would ever look bomb',
#  'suddenly lifted lion voice',
#  'dress anarchist fool',
#  'roared room shook',
#  'nobody ever expect anything dangerous',
#  'turned broad back without another word',
#  'took advice never regretted',
#  'preached blood murder women day night god would let wheel perambulators',
#  'syme sat watching respect large blue eyes',
#  'really smart dodge',
#  'call tremendous president',
#  'generally call sunday replied gregory simplicity',
#  'see seven members central anarchist council named days week',
#  'called sunday admirers bloody sunday',
#  'curious mention matter night dropped may express night london branch assembles room elect deputy fill vacancy council',
#  'gentleman time past played propriety general applause difficult part thursday died quite suddenly',
#  'consequently called meeting evening elect successor',
#  'got feet strolled across room sort smiling embarrassment',
#  'feel somehow mother syme continued casually',
#  'feel confide anything promised tell nobody',
#  'fact confide something would say many words anarchists coming room ten minutes',
#  'shall course go form election mind telling practically certain result',
#  'looked moment modestly',
#  'almost settled thing thursday',
#  'said syme heartily congratulate',
#  'gregory smiled deprecation walked across room talking rapidly',
#  'matter fact everything ready table said ceremony probably shortest possible',
#  'syme also strolled across table found lying across walking stick turned examination sword stick large colt revolver sandwich case formidable flask brandy',
#  'chair beside table thrown heavy looking cape cloak',
#  'get form election finished continued gregory animation snatch cloak stick stuff things pocket step door cavern opens river steam tug already waiting oh wild joy thursday',
#  'syme sat usual insolent languor got feet unusual air hesitation',
#  'asked vaguely think quite decent fellow',
#  'positively like gregory',
#  'paused moment added sort fresh curiosity ass',
#  'thoughtful silence cried',
#  'funniest situation ever life going act accordingly',
#  'gregory gave promise came place',
#  'promise would keep red hot pincers',
#  'would give safety little promise kind',
#  'asked gregory wondering',
#  'yes said syme seriously promise',
#  'swore god would tell secret police',
#  'swear humanity whatever beastly thing believe tell secret anarchists',
#  'asked staring gregory',
#  'yes said syme secret',
#  'gregory glared gravely moments said abruptly',
#  'must bewitched feel furious curiosity',
#  'yes swear tell anarchists anything tell',
#  'look sharp couple minutes',
#  'syme rose slowly feet thrust long white hands long grey trousers pockets',
#  'almost came five knocks outer grating proclaiming arrival first conspirators',
#  'well said syme slowly know tell truth shortly saying expedient dressing aimless poet confined president',
#  'known dodge time scotland yard',
#  'gregory tried spring straight swayed thrice',
#  'asked inhuman voice',
#  'yes said syme simply police detective',
#  'think hear friends coming',
#  'doorway came murmur mr joseph chamberlain',
#  'repeated twice thrice thirty times crowd joseph chamberlains solemn thought could heard trampling corridor',
#  'one fresh faces could appear doorway gregory stunned surprise fallen',
#  'beside table bound noise throat like wild beast',
#  'caught colt revolver took aim syme',
#  'syme flinch put pale polite hand',
#  'silly man said effeminate dignity curate',
#  'yes jolly sea sick',
#  'gregory could speak could fire either looked question',
#  'tell police anarchist',
#  'tell anarchists policeman',
#  'watch knowing watch knowing',
#  'short lonely intellectual duel head',
#  'policeman deprived help police',
#  'poor fellow anarchist deprived help law organisation essential anarchy',
#  'one solitary difference favour',
#  'surrounded inquisitive policemen surrounded inquisitive anarchists',
#  'cannot betray might betray',
#  'wait see betray',
#  'gregory put pistol slowly still staring syme sea monster',
#  'believe immortality said last break word god would make hell howl ever',
#  'shall break word said syme sternly break',
#  'mass anarchists entered room heavily slouching somewhat weary gait one little man black beard glasses man somewhat type mr tim healy detached bustled forward papers hand',
#  'comrade gregory said suppose man delegate',
#  'gregory taken surprise looked muttered name syme syme replied almost pertly',
#  'glad see gate well enough guarded make hard anyone delegate',
#  'brow little man black beard however still contracted something like suspicion',
#  'hardly call branch said syme laughing call least root',
#  'fact said syme serenely truth sabbatarian',
#  'specially sent see show due observance sunday',
#  'little man dropped one papers flicker fear went faces group',
#  'evidently awful president whose name sunday sometimes send irregular ambassadors branch meetings',
#  'well comrade said man papers pause suppose better give seat meeting',
#  'ask advice friend said syme severe benevolence think better',
#  'gregory heard dangerous dialogue end sudden safety rival rose abruptly paced floor painful thought',
#  'indeed agony diplomacy',
#  'clear syme inspired impudence likely bring merely accidental dilemmas',
#  'could betray syme partly honour partly also betrayed reason failed destroy syme escaped would syme freed obligation secrecy syme would simply walk nearest police station',
#  'one night discussion one detective would know',
#  'would let little possible plans night let syme go chance',
#  'strode across group anarchists already distributing along benches',
#  'think time began said steam tug waiting river already',
#  'move comrade buttons takes chair',
#  'approved show hands little man papers slipped presidential seat',
#  'comrades began sharp pistol shot meeting tonight important though need long',
#  'branch always honour electing thursdays central european council',
#  'elected many splendid thursdays',
#  'lament sad decease heroic worker occupied post last week',
#  'know services cause considerable',
#  'organised great dynamite coup brighton happier circumstances ought killed everybody pier',
#  'also know death self denying life died faith hygienic mixture chalk water substitute milk beverage regarded barbaric involving cruelty cow',
#  'cruelty anything approaching cruelty revolted always',
#  'acclaim virtues met harder task',
#  'difficult properly praise qualities difficult replace',
#  'upon comrades devolves evening choose company present man shall thursday',
#  'comrade suggests name put vote',
#  'comrade suggests name tell dear dynamiter gone us carried unknowable abysses last secret virtue innocence',
#  'stir almost inaudible applause sometimes heard church',
#  'large old man long venerable white beard perhaps real working man present rose lumberingly said',
#  'move comrade gregory elected thursday sat lumberingly',
#  'little man velvet coat pointed beard seconded',
#  'put matter vote said chairman call comrade gregory make statement',
#  'gregory rose amid great rumble applause',
#  'face deadly pale contrast queer red hair looked almost scarlet',
#  'smiling altogether ease',
#  'made mind saw best policy quite plain front like white road',
#  'best chance make softened ambiguous speech would leave detective mind impression anarchist brotherhood mild affair',
#  'believed literary power capacity suggesting fine shades picking perfect words',
#  'thought care could succeed spite people around conveying impression institution subtly delicately false',
#  'syme thought anarchists bravado playing fool',
#  'could hour peril make syme think',
#  'comrades began gregory low penetrating voice necessary tell policy policy also',
#  'belief slandered disfigured utterly confused concealed never altered',
#  'talk anarchism dangers go everywhere anywhere get information except us except fountain head',
#  'learn anarchists sixpenny novels learn anarchists tradesmen newspapers learn anarchists ally sloper half holiday sporting times',
#  'never learn anarchists anarchists',
#  'chance denying mountainous slanders heaped upon heads one end europe another',
#  'man always heard walking plagues never heard reply',
#  'know hear tonight though passion rend roof',
#  'deep deep earth persecuted permitted assemble christians assembled catacombs',
#  'incredible accident tonight man life thus immensely misunderstood us would put question christians met catacombs sort moral reputation streets',
#  'tales told atrocities one educated roman another',
#  'suppose would say suppose repeating still mysterious paradox history',
#  'suppose seem shocking christians really harmless christians',
#  'suppose seem mad christians really meek',
#  'applause greeted opening sentences gradually growing fainter last word stopped suddenly',
#  'abrupt silence man velvet jacket said high squeaky voice',
#  'comrade witherspoon tells us resumed gregory meek',
#  'ah little knows',
#  'words indeed extravagant appearance ferocious even ordinary taste unattractive',
#  'eye friendship deep delicate mine perceive deep foundation solid meekness lies base deep even see',
#  'repeat true early christians come late',
#  'simple revere simple look comrade witherspoon',
#  'modest modest look',
#  'called mr witherspoon velvet jacket',
#  'say merciful repeated gregory furiously early christians merciful',
#  'yet prevent accused eating human flesh',
#  'eat human flesh',
#  'comrade witherspoon said gregory feverish gaiety anxious know nobody eats laughter',
#  'society rate loves sincerely founded upon love',
#  'said witherspoon love',
#  'founded upon love repeated gregory grinding teeth difficulty aims shall pursue body pursue chosen representative body',
#  'superbly careless slanders represent us assassins enemies human society shall pursue moral courage quiet intellectual pressure permanent ideals brotherhood simplicity',
#  'gregory resumed seat passed hand across forehead',
#  'silence sudden awkward chairman rose like automaton said colourless voice',
#  'anyone oppose election comrade gregory',
#  'assembly seemed vague sub consciously disappointed comrade witherspoon moved restlessly seat muttered thick beard',
#  'sheer rush routine however motion would put carried',
#  'chairman opening mouth put syme sprang feet said small quiet voice',
#  'yes mr chairman oppose',
#  'effective fact oratory unexpected change voice',
#  'mr gabriel syme evidently understood oratory',
#  'said first formal words moderated tone brief simplicity made next word ring volley vault one guns gone',
#  'cried voice made every man jump boots come',
#  'live underground like rats order listen talk like',
#  'talk might listen eating buns sunday school treat',
#  'line walls weapons bar door death lest anyone come hear comrade gregory saying us good happy honesty best policy virtue reward',
#  'word comrade gregory address curate could listened pleasure hear hear',
#  'curate loud cheers listen pleasure renewed cheers',
#  'man fitted make good curate fitted make resolute forcible efficient thursday hear hear',
#  'comrade gregory told us apologetic tone enemies society',
#  'say enemies society much worse society',
#  'enemies society society enemy humanity oldest pitiless enemy hear hear',
#  'comrade gregory told us apologetically murderers',
#  'murderers executioners cheers',
#  'ever since syme risen gregory sat staring face idiotic astonishment',
#  'pause lips clay parted said automatic lifeless distinctness',
#  'syme looked straight frightful eyes pale blue ones said dignity',
#  'comrade gregory accuses hypocrisy',
#  'knows well keeping engagements nothing duty',
#  'say comrade gregory unfit thursday amiable qualities',
#  'unfit thursday amiable qualities',
#  'want supreme council anarchy infected maudlin mercy hear hear',
#  'time ceremonial politeness neither time ceremonial modesty',
#  'set comrade gregory would set governments europe anarchist given anarchy forgotten modesty much forgotten pride cheers',
#  'cause renewed cheers',
#  'set comrade gregory impersonally calmly choose one pistol rather another rack upon wall say rather gregory milk water methods supreme council would offer election',
#  'sentence drowned deafening cataract applause',
#  'faces grown fiercer fiercer approval tirade grew uncompromising distorted grins anticipation cloven delighted cries',
#  'moment announced ready stand post thursday roar excitement assent broke forth became uncontrollable moment gregory sprang feet foam upon mouth shouted shouting',
#  'stop blasted madmen',
#  'cried top voice tore throat',
#  'louder gregory shouting louder roar room came voice syme still speaking peal pitiless thunder',
#  'go council rebut slander calls us murderers go earn loud prolonged cheering',
#  'priest says men enemies religion judge says men enemies law fat parliamentarian says men enemies order public decency reply false kings true prophets',
#  'come destroy fulfil prophecies',
#  'heavy clamour gradually died away ceased witherspoon jumped feet hair beard end said',
#  'move amendment comrade syme appointed post',
#  'cried gregory frantic face hands',
#  'voice chairman clove speech cold accent',
#  'anyone second amendment',
#  'tall tired man melancholy eyes american chin beard observed back bench slowly rising feet',
#  'gregory screaming time past change accent shocking scream',
#  'said voice heavy stone',
#  'man cannot elected',
#  'yes said syme quite motionless',
#  'gregory mouth worked twice without sound slowly blood began crawl back dead face',
#  'man quite inexperienced work said sat abruptly',
#  'done long lean man american beard upon feet repeating high american monotone',
#  'beg second election comrade syme',
#  'amendment usual put first said mr buttons chairman mechanical rapidity',
#  'question comrade syme',
#  'gregory sprung feet panting passionate',
#  'comrades cried madman',
#  'said mr witherspoon',
#  'madman reiterated gregory frightful sincerity moment staggered room give counsel call mad like',
#  'call counsel give reason',
#  'call mad command act upon',
#  'truth terrible even fetters moment syme slender insane victory swayed like reed',
#  'could guessed syme bleak blue eyes',
#  'comrade gregory commands',
#  'spell snapped one anarchist called gregory',
#  'sunday another anarchist added heavier voice thursday',
#  'comrades cried gregory voice like martyr ecstacy pain passed beyond pain nothing whether detest tyrant detest slave',
#  'take command accept degradation',
#  'comrade gregory said chairman painful pause really quite dignified',
#  'first time proceedings seconds real silence',
#  'gregory fell back seat pale wreck man chairman repeated like piece clock work suddenly started',
#  'question comrade syme elected post thursday general council',
#  'roar rose like sea hands rose like forest three minutes afterwards mr gabriel syme secret police service elected post thursday general council anarchists europe',
#  'everyone room seemed feel tug waiting river sword stick revolver waiting table',
#  'instant election ended irrevocable syme received paper proving election sprang feet fiery groups moved mixed room',
#  'syme found somehow face face gregory still regarded stare stunned hatred',
#  'silent many minutes',
#  'said gregory last',
#  'gentleman said syme gravity',
#  'entrapped began gregory shaking head foot entrapped',
#  'talk sense said syme shortly',
#  'sort devils parliament entrapped comes',
#  'made swear made',
#  'perhaps think right',
#  'think right damned different nothing us way concession',
#  'nothing possible us honour death pulled great cloak shoulders picked flask table',
#  'boat quite ready said mr buttons bustling',
#  'good enough step way',
#  'gesture revealed shop walker led syme short iron bound passage still agonised gregory following feverishly heels',
#  'end passage door buttons opened sharply showing sudden blue silver picture moonlit river looked like scene theatre',
#  'close opening lay dark dwarfish steam launch like baby dragon one red eye',
#  'almost act stepping board gabriel syme turned gaping gregory',
#  'kept word said gently face shadow',
#  'man honour thank',
#  'kept even small particular',
#  'one special thing promised beginning affair certainly given end',
#  'cried chaotic gregory',
#  'entertaining evening said syme made military salute sword stick steamboat slid away',
#  'gabriel syme merely detective pretended poet really poet become detective',
#  'hatred anarchy hypocritical',
#  'one driven early life conservative attitude bewildering folly revolutionists',
#  'attained tame tradition',
#  'respectability spontaneous sudden rebellion rebellion',
#  'came family cranks oldest people newest notions',
#  'one uncles always walked without hat another made unsuccessful attempt walk hat nothing else',
#  'father cultivated art self realisation mother went simplicity hygiene',
#  'hence child tenderer years wholly unacquainted drink extremes absinth cocoa healthy dislike',
#  'mother preached puritan abstinence father expand pagan latitude time former come enforcing vegetarianism latter pretty well reached point defending cannibalism',
#  'surrounded every conceivable kind revolt infancy gabriel revolt something revolted thing left sanity',
#  'enough blood fanatics make even protest common sense little fierce sensible',
#  'hatred modern lawlessness crowned also accident',
#  'happened walking side street instant dynamite outrage',
#  'blind deaf moment seen smoke clearing broken windows bleeding faces',
#  'went usual quiet courteous rather gentle spot mind sane',
#  'regard anarchists us handful morbid men combining ignorance intellectualism',
#  'regarded huge pitiless peril like chinese invasion',
#  'poured perpetually newspapers waste paper baskets torrent tales verses violent articles warning men deluge barbaric denial',
#  'seemed getting nearer enemy worse nearer living',
#  'paced thames embankment bitterly biting cheap cigar brooding advance anarchy anarchist bomb pocket savage solitary',
#  'indeed always felt government stood alone desperate back wall',
#  'quixotic cared otherwise',
#  'walked embankment dark red sunset',
#  'red river reflected red sky reflected anger',
#  'sky indeed swarthy light river relatively lurid water almost seemed fiercer flame sunset mirrored',
#  'looked like stream literal fire winding vast caverns subterranean country',
#  'syme shabby days',
#  'wore old fashioned black chimney pot hat wrapped yet old fashioned cloak black ragged combination gave look early villains dickens bulwer lytton',
#  'also yellow beard hair unkempt leonine appeared long afterwards cut pointed lawns saffron park',
#  'long lean black cigar bought soho twopence stood tightened teeth altogether looked satisfactory specimen anarchists upon vowed holy war',
#  'perhaps policeman embankment spoke said good evening',
#  'syme crisis morbid fears humanity seemed stung mere stolidity automatic official mere bulk blue twilight',
#  'fellows would call end world good evening',
#  'look bloody red sun bloody river',
#  'tell literally human blood spilt shining would still standing solid ever looking poor harmless tramp could move',
#  'policemen cruel poor could forgive even cruelty calm',
#  'calm replied policeman calm organised resistance',
#  'said syme staring',
#  'soldier must calm thick battle pursued policeman',
#  'composure army anger nation',
#  'good god board schools',
#  'said policeman sadly never advantages',
#  'board schools came time',
#  'education rough old fashioned afraid',
#  'asked syme wondering',
#  'oh harrow said policeman',
#  'class sympathies false truest things many men broke syme could control',
#  'good lord man said oughtn policeman',
#  'policeman sighed shook head',
#  'know said solemnly know worthy',
#  'asked syme rude curiosity',
#  'much reason abused police replied',
#  'found special opening service whose fears humanity concerned rather aberrations scientific intellect normal excusable though excessive outbreaks human',
#  'trust make clear',
#  'mean make opinion clear said syme suppose',
#  'making clear last thing',
#  'comes man like talking philosophy blue helmet thames embankment',
#  'evidently heard latest development police system replied',
#  'keeping rather dark educated class class contains enemies',
#  'seem exactly right frame mind',
#  'think might almost join us',
#  'tell said policeman slowly',
#  'situation head one departments one celebrated detectives europe long opinion purely intellectual conspiracy would soon threaten existence civilisation',
#  'certain scientific artistic worlds silently bound crusade family state',
#  'therefore formed special corps policemen policemen also philosophers',
#  'business watch beginnings conspiracy merely criminal controversial sense',
#  'democrat fully aware value ordinary man matters ordinary valour virtue',
#  'would obviously undesirable employ common policeman investigation also heresy hunt',
#  'syme eyes bright sympathetic curiosity',
#  'work philosophical policeman replied man blue bolder subtle ordinary detective',
#  'ordinary detective goes pot houses arrest thieves go artistic tea parties detect pessimists',
#  'ordinary detective discovers ledger diary crime committed',
#  'discover book sonnets crime committed',
#  'trace origin dreadful thoughts drive men last intellectual fanaticism intellectual crime',
#  'time prevent assassination hartle pool entirely due fact mr wilks smart young fellow thoroughly understood triolet',
#  'mean asked syme really much connection crime modern intellect',
#  'sufficiently democratic answered policeman right said ordinary treatment poor criminal pretty brutal business',
#  'tell sometimes sick trade see perpetually means merely war upon ignorant desperate',
#  'new movement different affair',
#  'deny snobbish english assumption uneducated dangerous criminals',
#  'remember roman emperors',
#  'remember great poisoning princes renaissance',
#  'say dangerous criminal educated criminal',
#  'say dangerous criminal entirely lawless modern philosopher',
#  'compared burglars bigamists essentially moral men heart goes',
#  'accept essential ideal man merely seek wrongly',
#  'thieves respect property',
#  'merely wish property become property may perfectly respect',
#  'philosophers dislike property property wish destroy idea personal possession',
#  'bigamists respect marriage would go highly ceremonial even ritualistic formality bigamy',
#  'philosophers despise marriage marriage',
#  'murderers respect human life merely wish attain greater fulness human life sacrifice seems lesser lives',
#  'philosophers hate life much people',
#  'syme struck hands together',
#  'felt boyhood never could state verbal antithesis',
#  'common criminal bad man least conditional good man',
#  'says certain obstacle removed say wealthy uncle prepared accept universe praise god',
#  'wishes cleanse edifice destroy',
#  'evil philosopher trying alter things annihilate',
#  'yes modern world retained parts police work really oppressive ignominious harrying poor spying upon unfortunate',
#  'given dignified work punishment powerful traitors state powerful heresiarchs church',
#  'moderns say must punish heretics',
#  'doubt whether right punish anybody else',
#  'cried policeman clasping hands excitement uncommon persons figure costume intolerable',
#  'know wasting life',
#  'must shall join special army anarchy',
#  'bolt ready fall',
#  'moment may lose glory working us perhaps glory dying last heroes world',
#  'chance missed certainly assented syme still quite understand',
#  'know well anybody modern world full lawless little men mad little movements',
#  'beastly generally one merit disagreeing',
#  'talk leading one army hurling one bolt',
#  'confuse replied constable chance dynamite outbreaks russia ireland really outbreaks oppressed mistaken men',
#  'vast philosophic movement consisting outer inner ring',
#  'might even call outer ring laity inner ring priesthood',
#  'prefer call outer ring innocent section inner ring supremely guilty section',
#  'outer ring main mass supporters merely anarchists men believe rules formulas destroyed human happiness',
#  'believe evil results human crime results system called crime',
#  'believe crime creates punishment',
#  'believe punishment created crime',
#  'believe man seduced seven women would naturally walk away blameless flowers spring',
#  'believe man picked pocket would naturally feel exquisitely good',
#  'call innocent section',
#  'naturally therefore people talk happy time coming paradise future mankind freed bondage vice bondage virtue',
#  'also men inner circle speak sacred priesthood',
#  'also speak applauding crowds happiness future mankind freed last',
#  'mouths policeman lowered voice mouths happy phrases horrible meaning',
#  'illusions intellectual think man upon earth ever quite free original sin struggle',
#  'say mankind shall free last mean mankind shall commit suicide',
#  'talk paradise without right wrong mean grave',
#  'two objects destroy first humanity',
#  'throw bombs instead firing pistols',
#  'innocent rank file disappointed bomb killed king high priesthood happy killed somebody',
#  'asked syme sort passion',
#  'know fact vacancy moment said policeman honour somewhat confidence chief spoken',
#  'really come see',
#  'rather say see nobody ever sees talk like',
#  'inquired syme interest',
#  'said policeman placidly fancy always sitting pitch dark room',
#  'says makes thoughts brighter',
#  'somewhat dazed considerably excited syme allowed led side door long row buildings scotland yard',
#  'almost knew passed hands four intermediate officials suddenly shown room abrupt blackness startled like blaze light',
#  'ordinary darkness forms faintly traced like going suddenly stone blind',
#  'asked heavy voice',
#  'strange way though shadow shape gloom syme knew two things first came man massive stature second man back',
#  'said invisible chief seemed heard',
#  'syme quite swept feet made feeble fight irrevocable phrase',
#  'really experience began',
#  'one experience said battle armageddon',
#  'willing enough said unknown',
#  'well really said syme know profession mere willingness final test',
#  'thus gabriel syme came crimson light evening shabby black hat shabby lawless cloak came member new detective corps frustration great conspiracy',
#  'acting advice friend policeman professionally inclined neatness trimmed hair beard bought good hat clad exquisite summer suit light blue grey pale yellow flower button hole short became elegant rather insupportable person gregory first encountered little garden saffron park',
#  'finally left police premises friend provided small blue card written last crusade number sign official authority',
#  'put carefully upper waistcoat pocket lit cigarette went forth track fight enemy drawing rooms london',
#  'adventure ultimately led already seen',
#  'half past one february night found steaming small tug silent thames armed swordstick revolver duly elected thursday central council anarchists',
#  'syme stepped steam tug singular sensation stepping something entirely new merely landscape new land even landscape new planet',
#  'mainly due insane yet solid decision evening though partly also entire change weather sky since entered little tavern two hours',
#  'every trace passionate plumage cloudy sunset swept away naked moon stood naked sky',
#  'moon strong full paradox often noticed seemed like weaker sun',
#  'gave sense bright moonshine rather dead daylight',
#  'whole landscape lay luminous unnatural discoloration disastrous twilight milton spoke shed sun eclipse syme fell easily first thought actually emptier planet circled round sadder star',
#  'felt glittering desolation moonlit land chivalric folly glowed night like great fire',
#  'even common things carried food brandy loaded pistol took exactly concrete material poetry child feels takes gun upon journey bun bed',
# ...
#  'figure quite conventional clad silk hat frock coat formal type fashion red flower buttonhole',
#  'syme drew nearer step step even move hair syme could come close enough notice even dim pale morning light face long pale intellectual ended small triangular tuft dark beard point chin else clean shaven',
#  'scrap hair almost seemed mere oversight rest face type best shaven clear cut ascetic way noble',
#  'syme drew closer closer noting still figure stir',
#  'first instinct told syme man meant meet',
#  'seeing man made sign concluded',
#  'come back certainty man something mad adventure',
#  'man remained still would natural stranger come close',
#  'motionless wax work got nerves somewhat way',
#  'syme looked pale dignified delicate face face still looked blankly across river',
#  'took pocket note buttons proving election put sad beautiful face',
#  'man smiled smile shock one side going right cheek left',
#  'nothing rationally speaking scare anyone',
#  'many people nervous trick crooked smile many even attractive',
#  'syme circumstances dark dawn deadly errand loneliness great dripping stones something unnerving',
#  'silent river silent man man even classic face',
#  'last nightmare touch smile suddenly went wrong',
#  'spasm smile instantaneous man face dropped harmonious melancholy',
#  'spoke without explanation inquiry like man speaking old colleague',
#  'walk towards leicester square said shall time breakfast',
#  'sunday always insists early breakfast',
#  'answered man ordinary tone',
#  'shall try get bed breakfast',
#  'spoke casual civility utterly dead voice contradicted fanaticism face',
#  'seemed almost friendly words lifeless conveniences life hate',
#  'pause man spoke',
#  'course secretary branch told everything told',
#  'one thing never told last notion president notions grow like tropical forest',
#  'case know better tell carrying notion concealing concealing extraordinary lengths',
#  'originally course met cell underground branch',
#  'sunday made us take private room ordinary restaurant',
#  'said seem hiding nobody hunted',
#  'well man earth know sometimes really think huge brain going little mad old age',
#  'breakfast balcony balcony please overlooking leicester square',
#  'quite simple say answered guide',
#  'say lot jolly gentlemen pretend anarchists',
#  'seems clever idea said syme',
#  'god blast impudence',
#  'cried sudden shrill voice startling discordant crooked smile',
#  'seen sunday split second leave calling clever',
#  'emerged narrow street saw early sunlight filling leicester square',
#  'never known suppose square look alien ways continental',
#  'never known whether foreign look attracted foreigners foreigners gave foreign look',
#  'particular morning effect seemed singularly bright clear',
#  'open square sunlit leaves statue saracenic outlines alhambra looked replica french even spanish public place',
#  'effect increased syme sensation many shapes whole adventure eerie sensation strayed new world',
#  'fact bought bad cigars round leicester square ever since boy',
#  'turned corner saw trees moorish cupolas could sworn turning unknown place de something foreign town',
#  'one corner square projected kind angle prosperous quiet hotel bulk belonged street behind',
#  'wall one large french window probably window large coffee room outside window almost literally overhanging square formidably buttressed balcony big enough contain dining table',
#  'fact contain dining table strictly breakfast table round breakfast table glowing sunlight evident street group noisy talkative men dressed insolence fashion white waistcoats expensive button holes',
#  'jokes could almost heard across square',
#  'grave secretary gave unnatural smile syme knew boisterous breakfast party secret conclave european dynamiters',
#  'syme continued stare saw something seen',
#  'seen literally large see',
#  'nearest end balcony blocking great part perspective back great mountain man',
#  'syme seen first thought weight must break balcony stone',
#  'vastness lie fact abnormally tall quite incredibly fat',
#  'man planned enormously original proportions like statue carved deliberately colossal',
#  'head crowned white hair seen behind looked bigger head ought',
#  'ears stood looked larger human ears',
#  'enlarged terribly scale sense size staggering syme saw figures seemed quite suddenly dwindle become dwarfish',
#  'still sitting flowers frock coats looked big man entertaining five children tea',
#  'syme guide approached side door hotel waiter came smiling every tooth head',
#  'gentlemen sare said',
#  'talk laugh talk',
#  'say throw bombs ze king',
#  'waiter hurried away napkin arm much pleased singular frivolity gentlemen upstairs',
#  'two men mounted stairs silence',
#  'syme never thought asking whether monstrous man almost filled broke balcony great president others stood awe',
#  'knew unaccountable instantaneous certainty',
#  'syme indeed one men open nameless psychological influences degree little dangerous mental health',
#  'utterly devoid fear physical dangers great deal sensitive smell spiritual evil',
#  'twice already night little unmeaning things peeped almost pruriently given sense drawing nearer nearer head quarters hell',
#  'sense became overpowering drew nearer great president',
#  'form took childish yet hateful fancy',
#  'walked across inner room towards balcony large face sunday grew larger larger syme gripped fear quite close face would big possible would scream aloud',
#  'remembered child would look mask memnon british museum face large',
#  'effort braver leaping cliff went empty seat breakfast table sat',
#  'men greeted good humoured raillery always known',
#  'sobered little looking conventional coats solid shining coffee pot looked sunday',
#  'face large still possible humanity',
#  'presence president whole company looked sufficiently commonplace nothing caught eye first except president caprice dressed festive respectability gave meal look wedding breakfast',
#  'one man indeed stood even superficial glance',
#  'least common garden dynamiter',
#  'wore indeed high white collar satin tie uniform occasion collar sprang head quite unmanageable quite unmistakable bewildering bush brown hair beard almost obscured eyes like skye terrier',
#  'eyes look tangle sad eyes russian serf',
#  'effect figure terrible like president every diablerie come utterly grotesque',
#  'stiff tie collar come abruptly head cat dog could idiotic contrast',
#  'man name seemed gogol pole circle days called tuesday',
#  'soul speech incurably tragic could force play prosperous frivolous part demanded president sunday',
#  'indeed syme came president daring disregard public suspicion policy actually chaffing gogol upon inability assume conventional graces',
#  'friend tuesday said president deep voice quietude volume friend tuesday seem grasp idea',
#  'dresses like gentleman seems great soul behave like one',
#  'insists ways stage conspirator',
#  'gentleman goes london top hat frock coat one need know anarchist',
#  'gentleman puts top hat frock coat goes hands knees well may attract attention',
#  'goes hands knees inexhaustible diplomacy time finds quite difficult walk upright',
#  'good goncealment said gogol sulkily thick foreign accent ashamed cause',
#  'yes boy cause said president good naturedly',
#  'hide much anybody see ass',
#  'try combine two inconsistent methods',
#  'householder finds man bed probably pause note circumstance',
#  'finds man bed top hat agree dear tuesday likely even forget',
#  'found admiral biffin bed',
#  'good deception said tuesday gloomily flushing',
#  'right boy right said president ponderous heartiness good anything',
#  'stream conversation continued syme looking steadily men around',
#  'gradually felt sense something spiritually queer return',
#  'thought first common stature costume evident exception hairy gogol',
#  'looked others began see exactly seen man river demoniac detail somewhere',
#  'lop sided laugh would suddenly disfigure fine face original guide typical types',
#  'man something perceived perhaps tenth twentieth glance normal seemed hardly human',
#  'metaphor could think looked men fashion presence would look additional twist given false curved mirror',
#  'individual examples express half concealed eccentricity',
#  'syme original cicerone bore title monday secretary council twisted smile regarded terror anything except president horrible happy laughter',
#  'syme space light observe touches',
#  'fine face emaciated syme thought must wasted disease yet somehow distress dark eyes denied',
#  'physical ill troubled',
#  'eyes alive intellectual torture pure thought pain',
#  'typical tribe man subtly differently wrong',
#  'next sat tuesday tousle headed gogol man obviously mad',
#  'next wednesday certain marquis de st eustache sufficiently characteristic figure',
#  'first glances found nothing unusual except man table wore fashionable clothes really',
#  'black french beard cut square black english frock coat cut even squarer',
#  'syme sensitive things felt somehow man carried rich atmosphere rich atmosphere suffocated',
#  'reminded one irrationally drowsy odours dying lamps darker poems byron poe',
#  'went sense clad lighter colours softer materials black seemed richer warmer black shades compounded profound colour',
#  'black coat looked black dense purple',
#  'black beard looked black deep blue',
#  'gloom thickness beard dark red mouth showed sensual scornful',
#  'whatever frenchman might jew might something deeper yet dark heart east',
#  'bright coloured persian tiles pictures showing tyrants hunting may see almond eyes blue black beards cruel crimson lips',
#  'came syme next old man professor de worms still kept chair friday though every day expected death would leave empty',
#  'save intellect last dissolution senile decay',
#  'face grey long grey beard forehead lifted fixed finally furrow mild despair',
#  'case even gogol bridegroom brilliancy morning dress express painful contrast',
#  'red flower button hole showed face literally discoloured like lead whole hideous effect drunken dandies put clothes upon corpse',
#  'rose sat long labour peril something worse expressed mere weakness something indefinably connected horror whole scene',
#  'express decrepitude merely corruption',
#  'another hateful fancy crossed syme quivering mind',
#  'could help thinking whenever man moved leg arm might fall',
#  'right end sat man called saturday simplest baffling',
#  'short square man dark square face clean shaven medical practitioner going name bull',
#  'combination savoir faire sort well groomed coarseness uncommon young doctors',
#  'carried fine clothes confidence rather ease mostly wore set smile',
#  'nothing whatever odd except wore pair dark almost opaque spectacles',
#  'may merely crescendo nervous fancy gone black discs dreadful syme reminded half remembered ugly tales story pennies put eyes dead',
#  'syme eye always caught black glasses blind grin',
#  'dying professor worn even pale secretary would appropriate',
#  'younger grosser man seemed enigma',
#  'took away key face',
#  'could tell smile gravity meant',
#  'partly partly vulgar virility wanting others seemed syme might wickedest wicked men',
#  'syme even thought eyes might covered frightful see',
#  'six men sworn destroy world',
#  'syme strove pull together common sense presence',
#  'sometimes saw instant notions subjective looking ordinary men one old another nervous another short sighted',
#  'sense unnatural symbolism always settled back',
#  'figure seemed somehow borderland things theory borderland thought',
#  'knew one men stood extreme end speak wild road reasoning',
#  'could fancy old world fable man went westward end world would find something say tree less tree tree possessed spirit went east end world would find something else wholly tower perhaps shape wicked',
#  'figures seemed stand violent unaccountable ultimate horizon visions verge',
#  'ends earth closing',
#  'talk going steadily took scene least contrasts bewildering breakfast table contrast easy unobtrusive tone talk terrible purport',
#  'deep discussion actual immediate plot',
#  'waiter downstairs spoken quite correctly said talking bombs kings',
#  'three days afterwards czar meet president french republic paris bacon eggs upon sunny balcony beaming gentlemen decided die',
#  'even instrument chosen black bearded marquis appeared carry bomb',
#  'ordinarily speaking proximity positive objective crime would sobered syme cured merely mystical tremors',
#  'would thought nothing need saving least two human bodies ripped pieces iron roaring gas',
#  'truth time begun feel third kind fear piercing practical either moral revulsion social responsibility',
#  'simply fear spare french president czar begun fear',
#  'talkers took little heed debating faces closer together almost uniformly grave save instant smile secretary ran aslant across face jagged lightning runs aslant across sky',
#  'one persistent thing first troubled syme last terrified',
#  'president always looking steadily great baffling interest',
#  'enormous man quite quiet blue eyes stood head',
#  'always fixed syme',
#  'syme felt moved spring leap balcony',
#  'president eyes felt made glass',
#  'hardly shred doubt silent extraordinary way sunday found spy',
#  'looked edge balcony saw policeman standing abstractedly beneath staring bright railings sunlit trees',
#  'fell upon great temptation torment many days',
#  'presence powerful repulsive men princes anarchy almost forgotten frail fanciful figure poet gregory mere aesthete anarchism',
#  'even thought old kindness played together children',
#  'remembered still tied gregory great promise',
#  'promised never thing felt almost act',
#  'promised jump balcony speak policeman',
#  'took cold hand cold stone balustrade',
#  'soul swayed vertigo moral indecision',
#  'snap thread rash vow made villainous society life could open sunny square beneath',
#  'hand keep antiquated honour delivered inch inch power great enemy mankind whose intellect torture chamber',
#  'whenever looked square saw comfortable policeman pillar common sense common order',
#  'whenever looked back breakfast table saw president still quietly studying big unbearable eyes',
#  'torrent thought two thoughts never crossed mind',
#  'first never occurred doubt president council could crush continued stand alone',
#  'place might public project might seem impossible',
#  'sunday man would carry thus easily without somehow somewhere set open iron trap',
#  'either anonymous poison sudden street accident hypnotism fire hell sunday could certainly strike',
#  'defied man probably dead either struck stiff chair long afterwards innocent ailment',
#  'called police promptly arrested everyone told set whole energy england would probably escape certainly otherwise',
#  'balconyful gentlemen overlooking bright busy square felt safe boatful armed pirates overlooking empty sea',
#  'second thought never came',
#  'never occurred spiritually enemy',
#  'many moderns inured weak worship intellect force might wavered allegiance oppression great personality',
#  'might called sunday super man',
#  'creature conceivable looked indeed somewhat like earth shaking abstraction stone statue walking',
#  'might called something man large plans obvious detected large face frank understood',
#  'kind modern meanness syme could sink even extreme morbidity',
#  'like man coward enough fear great force quite coward enough admire',
#  'men eating talked even typical',
#  'dr bull marquis ate casually conventionally best things table cold pheasant strasbourg pie',
#  'secretary vegetarian spoke earnestly projected murder half raw tomato three quarters glass tepid water',
#  'old professor slops suggested sickening second childhood',
#  'even president sunday preserved curious predominance mere mass',
#  'ate like twenty men ate incredibly frightful freshness appetite like watching sausage factory',
#  'yet continually swallowed dozen crumpets drunk quart coffee would found great head one side staring syme',
#  'often wondered said marquis taking great bite slice bread jam whether better knife',
#  'best things brought knife',
#  'would new emotion get knife french president wriggle round',
#  ...]

# %%
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures

bigrams_num = 10

bigram_measures = BigramAssocMeasures()
finder = BigramCollocationFinder.from_documents([item.split() for item in thursday])
finder.nbest(bigram_measures.pmi, bigrams_num)
# Out:
# [('abandoned', 'boardroom'),
#  ('absinth', 'cocoa'),
#  ('acceptance', 'decisive'),
#  ('accepting', 'vein'),
#  ('accidental', 'dilemmas'),
#  ('acclaim', 'virtues'),
#  ('accuses', 'hypocrisy'),
#  ('acquainted', 'secretarial'),
#  ('additional', 'twist'),
#  ('admiral', 'biffin')]
